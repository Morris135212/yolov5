# %%
from inference import run
from models.common import DetectMultiBackend
import torch

# %%
weights = "./runs/train/exp/weights/best.pt"
source = "./dataset/pedestrain/Test/images/crop_000027.png"
data = "./data/custom.yaml"
imgsz = (416, 416)
view_img = True

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = DetectMultiBackend(weights, device=device, data=data)
run(model, device, source=source, imgsz=imgsz, view_img=view_img)
# Out:
# <PIL.Image.Image image mode=RGB size=729x720 at 0x158B6C100>
# runs/detect/exp/crop_000027.png

# %%
from inference import live_inference

weights = "./runs/train/exp/weights/best.pt"
# source = "./runs/detect/exp/tmp.mp4"
source = 0
data = "./data/custom.yaml"
imgsz = (416, 416)
view_img = True
live_inference(weights=weights, source=source, data=data, view_img=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x1657B5760>
