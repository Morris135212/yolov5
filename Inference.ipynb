# %%
from inference import run
from models.common import DetectMultiBackend
import torch
# Out:
# /Users/maochenhui/miniforge3/envs/DL/lib/python3.8/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")

# %%
weights = "./runs/train/exp/weights/best.pt"
source = "./dataset/pedestrain/Test/images/crop_000027.png"
data = "./data/custom.yaml"
imgsz = (416, 416)
view_img = True

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model = DetectMultiBackend(weights, device=device, data=data)
run(model, device, source=source, imgsz=imgsz, view_img=view_img)
# Out:
# <PIL.Image.Image image mode=RGB size=729x720 at 0x1505C69D0>
# array([[[135, 134, 123],
#         [131, 130, 116],
#         [129, 129, 113],
#         ...,
#         [121, 133, 131],
#         [118, 132, 129],
#         [122, 131, 130]],
#
#        [[137, 135, 127],
#         [131, 130, 117],
#         [129, 130, 114],
#         ...,
#         [122, 131, 129],
#         [121, 133, 131],
#         [124, 133, 133]],
#
#        [[131, 127, 126],
#         [131, 128, 120],
#         [128, 128, 116],
#         ...,
#         [122, 132, 130],
#         [118, 132, 129],
#         [119, 133, 130]],
#
#        ...,
#
#        [[156, 150, 148],
#         [155, 152, 147],
#         [154, 152, 147],
#         ...,
#         [128, 126, 124],
#         [124, 124, 120],
#         [126, 128, 120]],
#
#        [[153, 146, 144],
#         [154, 150, 146],
#         [157, 153, 149],
#         ...,
#         [129, 125, 124],
#         [125, 125, 121],
#         [127, 125, 119]],
#
#        [[158, 151, 147],
#         [156, 152, 147],
#         [158, 154, 149],
#         ...,
#         [126, 122, 121],
#         [126, 123, 121],
#         [128, 125, 120]]], dtype=uint8)

# %%
from inference import live_inference

weights = "./runs/train/exp/weights/best.pt"
# source = "./runs/detect/exp/result.mp4"
source = 0
data = "./data/custom.yaml"
imgsz = (416, 416)
view_img = True
live_inference(weights=weights, source=source, data=data, view_img=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x150724190>
# Detect Finish

# %% [markdown]
# #
